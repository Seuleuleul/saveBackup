# %% [markdown]
# <a href="https://colab.research.google.com/github/Seuleuleul/saveBackup/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd drive/MyDrive/yolov5/
# Out:
# /content/drive/MyDrive/yolov5

# %%
# !pip install -r requirements.txt

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="Q6vYtCvPJ1smbmnKhFIF")
project = rf.workspace("leeloo").project("leeloo-iyzwj")
dataset = project.version(1).download("yolov5")

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="Q6vYtCvPJ1smbmnKhFIF")
project = rf.workspace("leeloo").project("leeloo-iyzwj")
dataset = project.version(2).download("yolov5")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 KB 2.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 KB 3.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 KB 7.6 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 KB 8.4 MB/s eta 0:00:00
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9674 sha256=f627c7e4bcba61eb387bcba31dd0485f9fe8e2b296d422167e58b64109c29ce0
#   Stored in directory: /root/.cache/pip/wheels/bd/a8/c3/3cf2c14a1837a4e04bd98631724e81f33f462d86a1d895fae0
# Successfully built wget
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: pyparsing
# ...

# %%
# !pip install detect

# %%
# !pip install split-folders tqdm
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from procDataset import splits
splits("autoDatasetProcessor/detectedPlates", "autoDataset", (0.7, 0.1, 0.2))

# %%
# !python procDataset.py

# %%
# !unzip -qq '../images20000.zip'
# %cd ../..
# !pip install split-folders tqdm
# !python procDataset.py
# Out:
# /content/drive/MyDrive/yolov5
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# YOLOv5 🚀 v7.0-72-g064365d Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (NVIDIA A100-SXM4-40GB, 40536MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# Traceback (most recent call last):
#   File "procDataset.py", line 92, in <module>
#     main()
#   File "procDataset.py", line 88, in main
#     proc_dataset()
#   File "procDataset.py", line 33, in proc_dataset
#     detect.run(
#   File "/usr/local/lib/python3.8/dist-packages/torch/autograd/grad_mode.py", line 27, in decorate_context
#     return func(*args, **kwargs)
#   File "/content/drive/MyDrive/yolov5/detect.py", line 111, in run
#     dataset = LoadImages(source, img_size=imgsz, stride=stride, auto=pt, vid_stride=vid_stride)
#   File "/content/drive/MyDrive/yolov5/utils/dataloaders.py", line 273, in __init__
# ...

# %%
import shutil
import os
shutil.rmtree('runs/detect')
os.mkdir('runs/detect')

# %%
# %cd autoDatasetProcessor/unprocessedData/
# Out:
# /content/drive/MyDrive/yolov5/autoDatasetProcessor/unprocessedData

# %%
# !unzip -qq '../images20000.zip'

# %%
# !python train.py --img 640 --batch 8 --epochs 300 --data LeeLoo-2/data.yaml --weights yolov5s.pt --name manualDatasetTrain
# Out:
# train: weights=yolov5s.pt, cfg=, data=LeeLoo-2/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=300, batch_size=8, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=manualDatasetTrain, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 36 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v7.0-72-g064365d Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
# !python train.py --img 640 --batch 8 --epochs 300 --data autoDataset/data.yaml --weights autoDatasetProcessor/numberBestWeight/best.pt --name autoDatasetTrain
# Out:
# train: weights=autoDatasetProcessor/numberBestWeight/best.pt, cfg=, data=autoDataset/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=300, batch_size=8, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=autoDatasetTrain, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 36 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v7.0-72-g064365d Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (NVIDIA A100-SXM4-40GB, 40536MiB)
#
# ...

# %%
# !python customDetect.py --weights runs/train/manualDatasetTrain/weights/best.pt --name manualDatasetTrain
# Out:
# customDetect: weights=['runs/train/manualDatasetTrain/weights/best.pt'], source=data/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=manualDatasetTrain, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-72-g064365d Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7158460 parameters, 0 gradients, 16.2 GFLOPs
# image 1/50 /content/drive/MyDrive/yolov5/data/images/143_1.png: 182가6651
# image 2/50 /content/drive/MyDrive/yolov5/data/images/144_1.png: 45바버9762
# image 3/50 /content/drive/MyDrive/yolov5/data/images/145_1.png: 24마6451
# image 4/50 /content/drive/MyDrive/yolov5/data/images/146_1.png: 56마버8417
# ...

# %%
# !python customDetect.py --weights autoDatasetProcessor/numberBestWeight/weights_backup/best-0.pt --name autoDatasetTrain
# Out:
# customDetect: weights=['autoDatasetProcessor/numberBestWeight/weights_backup/best-0.pt'], source=data/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=autoDatasetTrain, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-72-g064365d Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7158460 parameters, 0 gradients, 16.2 GFLOPs
# image 1/50 /content/drive/MyDrive/yolov5/data/images/143_1.png: 182저가6651
# image 2/50 /content/drive/MyDrive/yolov5/data/images/144_1.png: 45버9762
# image 3/50 /content/drive/MyDrive/yolov5/data/images/145_1.png: 24마6451
# ...

# %%
# !python customDetect.py --weights autoDatasetProcessor/numberBestWeight/weights_backup/best-1.pt --name autoDatasetTrain
# Out:
# customDetect: weights=['autoDatasetProcessor/numberBestWeight/weights_backup/best-1.pt'], source=data/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=autoDatasetTrain, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-72-g064365d Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7158460 parameters, 0 gradients, 16.2 GFLOPs
# image 1/50 /content/drive/MyDrive/yolov5/data/images/143_1.png: 1826651
# image 2/50 /content/drive/MyDrive/yolov5/data/images/144_1.png: 459762
# image 3/50 /content/drive/MyDrive/yolov5/data/images/145_1.png: 246451
# image 4/50 /content/drive/MyDrive/yolov5/data/images/146_1.png: 568417
# ...

# %%
# !nvcc --version
